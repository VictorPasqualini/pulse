# %%
from pdfquery import PDFQuery

extract_picpay = PDFQuery('C:/Users/Victor Pasqualini/Downloads/report_63107944_29052024173910.pdf')
extract_picpay.load()
extract_picpay.tree.write('extrato-picpay.xml', pretty_print = True)
extract_picpay

# %%
# teste com PDFQuery
from pdfquery import PDFQuery

pdf = PDFQuery("C:/Users/Victor Pasqualini/projetos/github/vt-finances/ingt-raw-pdf/src/resources/pdf/picpay-all.pdf")
pdf.load()
#pdf.tree.write("C:/Users/Victor Pasqualini/projetos/github/vt-finances/ingt-raw-pdf/src/resources/xml/picpay-all.xml", pretty_print = True, encoding = "utf-8")

print('finalizado')

# %%
import pandas as pd

#name = pdf.pq('LTTextLineHorizontal:in_bbox("%s, %s, %s, %s")' % (x0, y0, x1, y1)).text()
#print(name)

#date_hour = pdf.extract([
#    ('with_parent','LTPage[page_index="0"]'),
#    ('with_formatter', 'text'),
#    ('spouse', 'LTTextLineHorizontal:in_bbox("27.0, 500.934, 68.456, 518.534")')
# ])["spouse"].split(' ')

number_pages = pdf.doc.catalog['Pages'].resolve()['Count']

df = pd.DataFrame({
    'data_mvtc': pd.Series(dtype='str'),
    'dcrc_mvtc': pd.Series(dtype='str'),
    'vlor_mvtc': pd.Series(dtype='float')
})

cols = len(df.axes[1])

print(data_mvtc)

for n in range(number_pages):
    
    y0_data_mvtc = 500.934
    y1_data_mvtc = 518.534
    
    y0_dcrc_vlor_mvtc = 505.734
    y1_dcrc_vlor_mvtc = 513.734

    data_mvtc = ' '
    
    while data_mvtc != '':
        
        data_mvtc = pdf.extract([
            ('with_parent','LTPage[page_index="%s"]' % (n)),
            ('with_formatter', 'text'),
            ('content', 'LTTextBoxHorizontal[y0="%s"][y1="%s"]' % (round(y0_data_mvtc, 3), round(y1_data_mvtc, 3)))
        ])['content']
        
        if data_mvtc == '':
            break

        data_mvtc = data_mvtc.replace('\n', ' ')

        dcrc_vlor_mvtc = pdf.extract([
            ('with_parent','LTPage[page_index="%s"]' % (n)),
            ('with_formatter', 'text'),
            ('content', 'LTTextBoxHorizontal[y0="%s"][y1="%s"]' % (round(y0_dcrc_vlor_mvtc, 3), round(y1_dcrc_vlor_mvtc, 3)))
        ])["content"]

        dcrc_vlor_mvtc = dcrc_vlor_mvtc.split('R$')

        dcrc_mvtc = dcrc_vlor_mvtc[0]
        vlor_mvtc = dcrc_vlor_mvtc[1]

        if '-' in dcrc_mvtc:
            dcrc_mvtc = dcrc_mvtc.replace('- ', '')
            vlor_mvtc = float(vlor_mvtc.replace(' ', '').replace('-', '').replace('.', '').replace(',', '.')) * (-1)
        else:
            vlor_mvtc = float(vlor_mvtc.replace(' ', '').replace('-', '').replace('.', '').replace(',', '.'))

        df.loc[-1] = [data_mvtc, dcrc_mvtc, vlor_mvtc]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()

        y0_data_mvtc -= 50
        y1_data_mvtc -= 50
        y0_dcrc_vlor_mvtc -= 50
        y1_dcrc_vlor_mvtc -= 50
    
display(df)

#date = date_hour[0]
#hour = date_hour[1]
# Out:
# 1  -  11
# 2  -  11
# 3  -  11
# 4  -  11
# 5  -  11
# 6  -  11
# 7  -  11
# 8  -  11
# 9  -  11
# 10  -  11
# 11  -  11
#               data_mvtc                                        dcrc_mvtc  \
# 0   29/04/2024 14:38:40                    Resgate na carteira Cofrinho
# 1   29/04/2024 17:53:28                Créditos utilizados em transação
# 2   29/04/2024 20:56:12             Aporte no Cofrinho Pelo Picpay Card
# 3   30/04/2024 07:55:46                    Resgate na carteira Cofrinho
# 4   30/04/2024 07:57:04  Aporte na carteira Cofrinho por compra parcial
# ..                  ...                                              ...
# 78  28/05/2024 19:37:35  Aporte na carteira Cofrinho por compra parcial
# 79  28/05/2024 20:34:10             Aporte no Cofrinho Pelo Picpay Card
# 80  28/05/2024 20:35:30             Aporte no Cofrinho Pelo Picpay Card
# 81  28/05/2024 20:59:03             Aporte no Cofrinho Pelo Picpay Card
# 82  29/05/2024 00:36:56             Aporte no Cofrinho Pelo Picpay Card
#
#     vlor_mvtc
# 0     1875.12
# 1      -10.00
# 2       -8.00
# 3     1351.47
# 4    -2080.62
# ..        ...
# 78      -0.43
# 79     -42.70
# 80     -26.90
# 81     -28.59
# 82     -29.92
#
# [83 rows x 3 columns]

# %%
vlor_mvtc = pdf.extract([
            ('with_parent','LTPage[page_index="%s"]' % (0)),
            ('with_formatter', 'text'),
            ('content', 'LTTextBoxHorizontal[y0="%s"][y1="%s"]' % (455.734, 463.734))
        ])["content"]

print(vlor_mvtc)
# Out:
# Aporte no Cofrinho Pelo Picpay Card - R$ 28,59 R$ 812,18 R$ 812,18

# %%
import json
import PyPDF2

# Open the PDF file
pdf_file = open('C:/Users/Victor Pasqualini/projetos/github/vt-finances/ingt-raw-pdf/src/resources/pdf/picpay.pdf', 'rb')

# Create a PDF reader object
pdf_reader = PyPDF2.PdfReader(pdf_file)

# Get the number of pages in the PDF file
num_pages = len(pdf_reader.pages)

# Loop through all the pages and extract the text
for page in range(num_pages):
    page_obj = pdf_reader.pages[page]
    print(page_obj.extract_text())
    
# Close the PDF file
pdf_file.close()
# Out:
# 1 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 1 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 29/05/2024
# 00:36:56Aporte no Cofrinho Pelo Picpay Card - R$ 29,92 - -
# 28/05/2024
# 20:59:03Aporte no Cofrinho Pelo Picpay Card - R$ 28,59 R$ 812,18 R$ 812,18
# 28/05/2024
# 20:35:30Aporte no Cofrinho Pelo Picpay Card - R$ 26,90 - -
# 28/05/2024
# 20:34:10Aporte no Cofrinho Pelo Picpay Card - R$ 42,70 - -
# 28/05/2024
# 19:37:35Aporte na carteira Cofrinho por compra parcial - R$ 0,43 - -
# 28/05/2024
# 18:30:47Aporte na carteira Cofrinho por compra parcial - R$ 27,96 - -
# 28/05/2024
# 14:29:31Aporte no Cofrinho Pelo Picpay Card - R$ 82,08 - -
# 28/05/2024
# 14:26:24Resgate na carteira Cofrinho R$ 1.000,00 - -
# 2 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 2 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 27/05/2024
# 20:39:50Aporte na carteira Cofrinho por compra parcial - R$ 1,46 R$ 20,84 R$ 20,84
# 27/05/2024
# 18:10:10Débito utilizado em transação para recarga de cartão de transporte - R$ 20,00 - -
# 26/05/2024
# 19:29:58Aporte no Cofrinho Pelo Picpay Card - R$ 16,52 R$ 42,30 R$ 42,30
# 26/05/2024
# 18:42:38Pix Enviado - R$ 19,57 - -
# 25/05/2024
# 22:43:10Pix Recebido R$ 30,00 R$ 78,39 R$ 78,39
# 25/05/2024
# 22:02:46Aporte no Cofrinho Pelo Picpay Card - R$ 95,81 - -
# 25/05/2024
# 18:02:43Aporte no Cofrinho Pelo Picpay Card - R$ 23,00 - -
# 25/05/2024
# 13:35:38Aporte na carteira Cofrinho por compra parcial - R$ 2,54 - -
# 3 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 3 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 25/05/2024
# 08:03:11Débito utilizado em transação para recarga de cartão de transporte - R$ 20,00 - -
# 25/05/2024
# 01:46:56Aporte no Cofrinho Pelo Picpay Card - R$ 56,78 - -
# 25/05/2024
# 00:33:14Aporte no Cofrinho Pelo Picpay Card - R$ 58,69 - -
# 25/05/2024
# 00:30:04Aporte no Cofrinho Pelo Picpay Card - R$ 82,72 - -
# 24/05/2024
# 20:28:57Aporte no Cofrinho Pelo Picpay Card - R$ 12,91 R$ 387,93 R$ 387,93
# 24/05/2024
# 16:19:46Aporte na carteira Cofrinho por compra parcial - R$ 53,14 - -
# 23/05/2024
# 12:56:30Aporte no Cofrinho Pelo Picpay Card - R$ 14,99 R$ 453,98 R$ 453,98
# 22/05/2024
# 20:54:57Aporte na carteira Cofrinho por compra parcial - R$ 8,07 R$ 468,97 R$ 468,97
# 4 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 4 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 22/05/2024
# 20:48:30Aporte na carteira Cofrinho por compra parcial - R$ 6,57 - -
# 22/05/2024
# 17:55:04Créditos utilizados em transação - R$ 10,00 - -
# 21/05/2024
# 19:21:25Aporte na carteira Cofrinho por compra parcial - R$ 237,53 R$ 493,61 R$ 493,61
# 21/05/2024
# 14:29:42Pix Enviado - R$ 234,25 - -
# 20/05/2024
# 20:40:00Aporte na carteira Cofrinho por compra parcial - R$ 21,73 R$ 965,39 R$ 965,39
# 20/05/2024
# 16:28:35Aporte na carteira Cofrinho por compra parcial - R$ 61,93 - -
# 19/05/2024
# 18:16:31Aporte na carteira Cofrinho por compra parcial - R$ 68,93 R$ 1.049,05 R$ 1.049,05
# 18/05/2024
# 23:25:01Pix Enviado - R$ 18,00 R$ 1.117,98 R$ 1.117,98
# 5 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 5 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 18/05/2024
# 20:14:42Aporte na carteira Cofrinho por compra parcial - R$ 7,79 - -
# 18/05/2024
# 17:40:49Créditos utilizados em transação - R$ 20,00 - -
# 17/05/2024
# 20:04:22Pix Recebido R$ 40,00 R$ 1.163,77 R$ 1.163,77
# 17/05/2024
# 19:13:37Aporte na carteira Cofrinho por compra parcial - R$ 8,19 - -
# 17/05/2024
# 18:52:22Aporte no Cofrinho Pelo Picpay Card - R$ 20,06 - -
# 17/05/2024
# 18:26:36Aporte no Cofrinho Pelo Picpay Card - R$ 19,98 - -
# 17/05/2024
# 18:23:52Aporte na carteira Cofrinho por compra parcial - R$ 17,22 - -
# 17/05/2024
# 15:44:16Aporte na carteira Cofrinho por compra parcial - R$ 73,23 - -
# 6 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 6 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 16/05/2024
# 16:00:41Saldo adicionado por lojista R$ 16,32 R$ 1.262,45 R$ 1.262,45
# 16/05/2024
# 15:57:37Saldo adicionado por lojista R$ 1,88 - -
# 16/05/2024
# 15:24:35Aporte na carteira Cofrinho por compra parcial - R$ 11,33 - -
# 15/05/2024
# 12:55:49Aporte na carteira Cofrinho por compra parcial - R$ 9,30 R$ 1.255,58 R$ 1.255,58
# 15/05/2024
# 10:10:39Pix Enviado - R$ 6.813,95 - -
# 15/05/2024
# 10:04:18Pix Recebido R$ 6.909,84 - -
# 13/05/2024
# 23:42:06Aporte na carteira Cofrinho por compra parcial - R$ 2,10 R$ 1.168,99 R$ 1.168,99
# 13/05/2024
# 21:02:38Pix Enviado - R$ 8,00 - -
# 7 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 7 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 13/05/2024
# 18:13:42Créditos utilizados em transação - R$ 10,00 - -
# 12/05/2024
# 22:33:46Pix Enviado - R$ 17,55 R$ 1.189,09 R$ 1.189,09
# 12/05/2024
# 04:10:01Aporte no Cofrinho Pelo Picpay Card - R$ 11,14 - -
# 12/05/2024
# 02:59:54Aporte no Cofrinho Pelo Picpay Card - R$ 12,00 - -
# 12/05/2024
# 02:59:19Aporte no Cofrinho Pelo Picpay Card - R$ 24,57 - -
# 11/05/2024
# 23:23:52Aporte no Cofrinho Pelo Picpay Card - R$ 150,00 R$ 1.254,35 R$ 1.254,35
# 11/05/2024
# 23:17:55Aporte no Cofrinho Pelo Picpay Card - R$ 6,60 - -
# 11/05/2024
# 22:55:39Aporte na carteira Cofrinho por compra parcial - R$ 6,87 - -
# 8 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 8 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 11/05/2024
# 21:52:32Aporte no Cofrinho Pelo Picpay Card - R$ 93,70 - -
# 11/05/2024
# 21:24:05Aporte no Cofrinho Pelo Picpay Card - R$ 11,68 - -
# 11/05/2024
# 20:44:32Pix Enviado - R$ 20,00 - -
# 11/05/2024
# 19:19:22Aporte no Cofrinho Pelo Picpay Card - R$ 17,86 - -
# 11/05/2024
# 02:23:30Aporte no Cofrinho Pelo Picpay Card - R$ 9,23 - -
# 11/05/2024
# 02:22:42Aporte na carteira Cofrinho por compra parcial - R$ 4,39 - -
# 10/05/2024
# 21:36:12Aporte no Cofrinho Pelo Picpay Card - R$ 26,89 R$ 1.574,68 R$ 1.574,68
# 10/05/2024
# 20:06:23Aporte no Cofrinho Pelo Picpay Card - R$ 51,00 - -
# 9 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 9 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 10/05/2024
# 19:26:38Aporte na carteira Cofrinho por compra parcial - R$ 22,01 - -
# 10/05/2024
# 12:50:10Aporte no Cofrinho Pelo Picpay Card - R$ 42,23 - -
# 10/05/2024
# 12:34:17Aporte na carteira Cofrinho por compra parcial - R$ 174,99 - -
# 10/05/2024
# 11:35:53Pix Enviado - R$ 106,15 - -
# 10/05/2024
# 11:35:26Pix Enviado - R$ 215,44 - -
# 10/05/2024
# 07:37:31Pix Recebido R$ 100,00 - -
# 09/05/2024
# 02:21:46Aporte no Cofrinho Pelo Picpay Card - R$ 36,00 R$ 2.113,39 R$ 2.113,39
# 08/05/2024
# 21:09:26Aporte na carteira Cofrinho por compra parcial - R$ 6,54 R$ 2.149,39 R$ 2.149,39
# 10 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 10 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 08/05/2024
# 17:37:56Créditos utilizados em transação - R$ 10,00 - -
# 08/05/2024
# 12:56:46Aporte na carteira Cofrinho por compra parcial - R$ 21,54 - -
# 08/05/2024
# 10:25:04Pix Enviado - R$ 316,82 - -
# 06/05/2024
# 23:53:05Aporte no Cofrinho Pelo Picpay Card - R$ 7,49 R$ 2.504,29 R$ 2.504,29
# 06/05/2024
# 21:02:58Aporte na carteira Cofrinho por compra parcial - R$ 13,05 - -
# 06/05/2024
# 18:12:49Créditos utilizados em transação - R$ 10,00 - -
# 30/04/2024
# 07:57:04Aporte na carteira Cofrinho por compra parcial - R$ 2.080,62 R$ 2.534,83 R$ 2.534,83
# 30/04/2024
# 07:55:46Resgate na carteira Cofrinho R$ 1.351,47 - -
# 11 de 11
# @victor.pasqualini
# Victor Ramos Pasqualini
# CPF: 518.534.598-52        Agência: 0001         Conta: 709903197
# Cliente desde: 02/12/2021
# MOVIMENTAÇÕES 29 DE ABRIL DE 2024 A 29 DE MAIO DE 2024​
# Extrato gerado em 29/05/2024 às 14:39:11
# PicPay Serviços S.A. - CNPJ: 22.896.431/0001-10
# Se você ﬁcou com alguma dúvida sobre os valores registrados no
# seu extrato, entre em contato em nossa Ouvidoria.Dias úteis das 09h às 18h
# Telefone: 0800 025 2000
# 11 de 11Data/Hora Descrição das Movimentações Valor Saldo Saldo Sacável
# 29/04/2024
# 20:56:12Aporte no Cofrinho Pelo Picpay Card - R$ 8,00 R$ 3.263,98 R$ 3.263,98
# 29/04/2024
# 17:53:28Créditos utilizados em transação - R$ 10,00 - -
# 29/04/2024
# 14:38:40Resgate na carteira Cofrinho R$ 1.875,12 - -
