# %%
from pdfquery import PDFQuery

pdf_file = PDFQuery('C:/Users/Victor Pasqualini/Downloads/PicPay_Fatura_052024.pdf')
pdf_file.load()

pdf_file.tree.write('fatura-picpay.xml', pretty_print = True)
pdf_file

# %%
example = pdf_file.pq('LTTextLineHorizontal:in_bbox("301.35, 496.277, 412.491, 506.287")').text()
print(example)
# Out:
# Transações Nacionais

# %%
pdf_file = PDFQuery('C:/Users/Victor Pasqualini/Downloads/report_63107944_29052024172959.pdf')
pdf_file.load()

pdf_file.tree.write('extrato-picpay.xml', pretty_print = True)
pdf_file

# %%
example = pdf_file.pq('LTTextLineHorizontal:in_bbox("301.35, 496.277, 412.491, 506.287")').text()
print(example)
